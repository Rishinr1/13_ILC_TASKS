# %%
import pandas as pd
import pyarrow.parquet as pq

# Prompt the user to enter the path to the Parquet file
file_path2 = (r"D:\RISHIN\13_ILC_TASK1\input\EXPORT\ILC2024_EUWS_PLA_WI_EP_BE_EUR_Losses\ILC2024_EUWS_PLA_WI_EP_BE_EUR_Losses\EP\Lob\GU\ILC2024_EUWS_PLA_WI_EP_BE_EUR_EP_Lob_GU_4.parquet")

# Ensure the file path is treated as a raw string and strip any extra quotes

# Read the Parquet file into a PyArrow Table
table2 = pq.read_table(file_path2)

# Convert the PyArrow Table to a Pandas DataFrame
df2 = table2.to_pandas()

# %%
df2
# Out:
#      EPType          Loss  ReturnPeriod LobId LobName
# 0       OEP  1.378075e+10       10000.0     5    SPER
# 1       OEP  1.029308e+10        5000.0     5    SPER
# 2       OEP  5.645112e+09        1000.0     5    SPER
# 3       OEP  4.098577e+09         500.0     5    SPER
# 4       OEP  2.681864e+09         250.0     5    SPER
# 5       OEP  2.381524e+09         200.0     5    SPER
# 6       OEP  1.502044e+09         100.0     5    SPER
# 7       OEP  9.059202e+08          50.0     5    SPER
# 8       OEP  5.545406e+08          25.0     5    SPER
# 9       OEP  2.638986e+08          10.0     5    SPER
# 10      OEP  1.333812e+08           5.0     5    SPER
# 11      OEP  2.847476e+07           2.0     5    SPER
# 12      AEP  1.378475e+10       10000.0     5    SPER
# 13      AEP  1.072958e+10        5000.0     5    SPER
# 14      AEP  5.928231e+09        1000.0     5    SPER
# 15      AEP  4.441338e+09         500.0     5    SPER
# 16      AEP  3.022789e+09         250.0     5    SPER
# 17      AEP  2.685408e+09         200.0     5    SPER
# 18      AEP  1.804945e+09         100.0     5    SPER
# 19      AEP  1.173781e+09          50.0     5    SPER
# 20      AEP  7.510327e+08          25.0     5    SPER
# 21      AEP  3.783575e+08          10.0     5    SPER
# 22      AEP  1.946077e+08           5.0     5    SPER
# 23      AEP  4.526104e+07           2.0     5    SPER
# 24  TCE-OEP  1.743200e+10       10000.0     5    SPER
# 25  TCE-OEP  1.445363e+10        5000.0     5    SPER
# 26  TCE-OEP  8.637114e+09        1000.0     5    SPER
# 27  TCE-OEP  6.683911e+09         500.0     5    SPER
# 28  TCE-OEP  4.980489e+09         250.0     5    SPER
# 29  TCE-OEP  4.489511e+09         200.0     5    SPER
# 30  TCE-OEP  3.177247e+09         100.0     5    SPER
# 31  TCE-OEP  2.161242e+09          50.0     5    SPER
# 32  TCE-OEP  1.429062e+09          25.0     5    SPER
# 33  TCE-OEP  7.972195e+08          10.0     5    SPER
# 34  TCE-OEP  4.922490e+08           5.0     5    SPER
# 35  TCE-OEP  2.366651e+08           2.0     5    SPER
# 36  TCE-AEP  1.770516e+10       10000.0     5    SPER
# 37  TCE-AEP  1.481754e+10        5000.0     5    SPER
# 38  TCE-AEP  8.962481e+09        1000.0     5    SPER
# 39  TCE-AEP  7.005230e+09         500.0     5    SPER
# 40  TCE-AEP  5.322227e+09         250.0     5    SPER
# 41  TCE-AEP  4.828576e+09         200.0     5    SPER
# 42  TCE-AEP  3.496832e+09         100.0     5    SPER
# 43  TCE-AEP  2.464722e+09          50.0     5    SPER
# 44  TCE-AEP  1.694162e+09          25.0     5    SPER
# 45  TCE-AEP  9.911965e+08          10.0     5    SPER
# 46  TCE-AEP  6.304739e+08           5.0     5    SPER
# 47  TCE-AEP  3.121793e+08           2.0     5    SPER

# %%
import pandas as pd
import pyarrow.parquet as pq

# Prompt the user to enter the path to the Parquet file
file_path3 = (r"D:\RISHIN\Rough\ILC2024_EUWS_PLA_WI_EP_BE_EUR_Losses\EP\Lob\GU\ILC2024_EUWS_PLA_WI_EP_BE_EUR_EP_Lob_GU_5.parquet")

# Ensure the file path is treated as a raw string and strip any extra quotes

# Read the Parquet file into a PyArrow Table
table3 = pq.read_table(file_path3)

# Convert the PyArrow Table to a Pandas DataFrame
df3 = table3.to_pandas()

# %%
df3
# Out:
# Empty DataFrame
# Columns: [EPType, Loss, ReturnPeriod, LobId, LobName]
# Index: []
